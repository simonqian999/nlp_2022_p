# %%
import requests
import os
import json
from pprint import pprint

# os.environ['BEARER_TOKEN'] = 'WRITE YOUR TOKEN HERE'
bearer_token = os.environ.get('BEARER_TOKEN')

def create_url(ids):
    tweet_fields = "tweet.fields=lang,author_id,attachments,context_annotations,conversation_id,created_at,entities,geo,id,public_metrics,withheld"
    expansion = "expansions=author_id"
    author_fields = "user.fields=id,name,username,created_at,description,entities,location,public_metrics,protected,verified,withheld"
    
    url = "https://api.twitter.com/2/tweets/{}?{}&{}&{}".format(ids, tweet_fields, expansion, author_fields)
    return url


def get_tweet(_id):
    url = create_url(_id)
    payload={}
    headers = {
      'Authorization': 'Bearer {}'.format(bearer_token),
      'Cookie': 'guest_id=v1%3A164999832374703747; guest_id_ads=v1%3A164999832374703747; guest_id_marketing=v1%3A164999832374703747; personalization_id="v1_+F68isE/iukb7yr8y66bOw=="'
    }

    response = requests.request("GET", url, headers=headers, data=payload)
    
    return response.json()

'''
def main():
    url = create_url()
    json_response = connect_to_endpoint(url)
    print(json.dumps(json_response, indent=4, sort_keys=True))
'''
'''
if __name__ == "__main__":
    main()
    '''
# Out:
# '\nif __name__ == "__main__":\n    main()\n    '

# %%
import pandas as pd

def read_file(file_name):
    '''
    This function will read the file containing tweet ids sperating by lines (in groups)
    '''
    all_ids = pd.read_table(file_name,sep='\n',header=None)
    return all_ids

# %%
def separate_ids(ids):
    '''
    This function will split the sperate ids into a list
    '''
    seperated_ids = ids.split(",")
    return seperated_ids

# %%
def get_tweet_groups(groups_ids):
    '''
    This function will get tweets information using Twitter API in groups and indexing them
    params groups_ids: all ids in lines (groups) retrieved from the orginal file 
    '''
    tweet_groups = {}
    for group_index in range(len(groups_ids)):
        group_separeted_ids =  separate_ids(train_ids[0][group_index])

        group_dict = {}
        index_in_group = 0
        for _id in group_separeted_ids:
            group_dict[index_in_group] = get_tweet(_id)
            index_in_group += 1
        tweet_groups[group_index] = group_dict
    return tweet_groups

# %%
train_ids = read_file('../../project-data/train.data.txt')
tweets_train = get_tweet_groups(train_ids[0:2])

# %%
pprint(tweets_train[0])
# Out:
# {0: {'data': {'attachments': {'media_keys': ['3_1250219288406810624']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:28:03.000Z',
#               'entities': {'urls': [{'display_url': 'pic.twitter.com/ccMjhhD7BK',
#                                      'end': 119,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250219300389974016/photo/1',
#                                      'start': 96,
#                                      'url': 'https://t.co/ccMjhhD7BK'}]},
#               'id': '1250219300389974016',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '5. Can regularly rinsing your nose with saline help '
#                       'prevent infection with the new coronavirus? '
#                       'https://t.co/ccMjhhD7BK'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  1: {'data': {'attachments': {'media_keys': ['3_1250219081166254081']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}},
#                                       {'domain': {'description': 'Entity '
#                                                                  'Service top '
#                                                                  'level '
#                                                                  'domain, '
#                                                                  'every item '
#                                                                  'that is in '
#                                                                  'Entity '
#                                                                  'Service '
#                                                                  'should be in '
#                                                                  'this domain',
#                                                   'id': '30',
#                                                   'name': 'Entities [Entity '
#                                                           'Service]'},
#                                        'entity': {'description': 'Food',
#                                                   'id': '825047692124442624',
#                                                   'name': 'Food'}},
#                                       {'domain': {'description': 'Entity '
#                                                                  'Service top '
#                                                                  'level '
#                                                                  'domain, '
#                                                                  'every item '
#                                                                  'that is in '
#                                                                  'Entity '
#                                                                  'Service '
#                                                                  'should be in '
#                                                                  'this domain',
#                                                   'id': '30',
#                                                   'name': 'Entities [Entity '
#                                                           'Service]'},
#                                        'entity': {'description': 'Generic Food',
#                                                   'id': '824777229892661248',
#                                                   'name': 'Generic Food'}},
#                                       {'domain': {'description': 'Entity '
#                                                                  'Service top '
#                                                                  'level '
#                                                                  'domain, '
#                                                                  'every item '
#                                                                  'that is in '
#                                                                  'Entity '
#                                                                  'Service '
#                                                                  'should be in '
#                                                                  'this domain',
#                                                   'id': '30',
#                                                   'name': 'Entities [Entity '
#                                                           'Service]'},
#                                        'entity': {'description': 'Vegetables',
#                                                   'id': '842797798626009088',
#                                                   'name': 'Vegetable '
#                                                           'recipes'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:27:20.000Z',
#               'entities': {'hashtags': [{'end': 86,
#                                          'start': 70,
#                                          'tag': 'COVID19Malaysia'}],
#                            'urls': [{'display_url': 'pic.twitter.com/q133xXBiwl',
#                                      'end': 110,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250219116993974272/photo/1',
#                                      'start': 87,
#                                      'url': 'https://t.co/q133xXBiwl'}]},
#               'id': '1250219116993974272',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '4. Can eating garlic help prevent infection with the '
#                       'new coronavirus? #COVID19Malaysia '
#                       'https://t.co/q133xXBiwl'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  2: {'data': {'attachments': {'media_keys': ['3_1250219431004745729']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:28:36.000Z',
#               'entities': {'urls': [{'display_url': 'pic.twitter.com/wL0mlEqU95',
#                                      'end': 97,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250219437027766273/photo/1',
#                                      'start': 74,
#                                      'url': 'https://t.co/wL0mlEqU95'}]},
#               'id': '1250219437027766273',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '6. Do vaccines against pneumonia protect you against '
#                       'the new coronavirus? https://t.co/wL0mlEqU95'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  3: {'data': {'attachments': {'media_keys': ['3_1250219494405844992']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:29:20.000Z',
#               'entities': {'hashtags': [{'end': 89,
#                                          'start': 81,
#                                          'tag': 'Chamber'}],
#                            'urls': [{'display_url': 'pic.twitter.com/zunVR7Ht0V',
#                                      'end': 113,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250219620939657216/photo/1',
#                                      'start': 90,
#                                      'url': 'https://t.co/zunVR7Ht0V'}]},
#               'id': '1250219620939657216',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '7. Can spraying alcohol or chlorine all over your body '
#                       'kill the new coronavirus? #Chamber '
#                       'https://t.co/zunVR7Ht0V'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  4: {'data': {'attachments': {'media_keys': ['3_1250219766691708928']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:29:57.000Z',
#               'entities': {'urls': [{'display_url': 'pic.twitter.com/nyLOyKAb1H',
#                                      'end': 116,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250219777185873922/photo/1',
#                                      'start': 93,
#                                      'url': 'https://t.co/nyLOyKAb1H'}]},
#               'id': '1250219777185873922',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '8. How effective are thermal scanners in detecting '
#                       'people infected with the new coronavirus? '
#                       'https://t.co/nyLOyKAb1H'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  5: {'data': {'attachments': {'media_keys': ['3_1250219886543953922']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:30:25.000Z',
#               'entities': {'urls': [{'display_url': 'pic.twitter.com/ZrlllbkIjm',
#                                      'end': 89,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250219894429208577/photo/1',
#                                      'start': 66,
#                                      'url': 'https://t.co/ZrlllbkIjm'}]},
#               'id': '1250219894429208577',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '9. Can an ultraviolet disinfection lamp kill the new '
#                       'coronavirus? https://t.co/ZrlllbkIjm'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  6: {'data': {'attachments': {'media_keys': ['3_1250219939102769157']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:30:50.000Z',
#               'entities': {'urls': [{'display_url': 'pic.twitter.com/cSDKXO1bGr',
#                                      'end': 85,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250219998842216448/photo/1',
#                                      'start': 62,
#                                      'url': 'https://t.co/cSDKXO1bGr'}]},
#               'id': '1250219998842216448',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '10. Are hand dryers effective in killing the new '
#                       'coronavirus? https://t.co/cSDKXO1bGr'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  7: {'data': {'attachments': {'media_keys': ['3_1250220108611379200']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:31:18.000Z',
#               'entities': {'urls': [{'display_url': 'pic.twitter.com/ZRL8bjRkpl',
#                                      'end': 93,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250220115762667520/photo/1',
#                                      'start': 70,
#                                      'url': 'https://t.co/ZRL8bjRkpl'}]},
#               'id': '1250220115762667520',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '11. The new coronavirus CANNOT be transmitted through '
#                       'mosquito bites. https://t.co/ZRL8bjRkpl'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  8: {'data': {'attachments': {'media_keys': ['3_1250220258423484416']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:31:55.000Z',
#               'entities': {'urls': [{'display_url': 'pic.twitter.com/bICOqSTOuD',
#                                      'end': 90,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250220272306638848/photo/1',
#                                      'start': 67,
#                                      'url': 'https://t.co/bICOqSTOuD'}]},
#               'id': '1250220272306638848',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '12. Taking a hot bath does not prevent the new '
#                       'coronavirus disease https://t.co/bICOqSTOuD'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  9: {'data': {'attachments': {'media_keys': ['3_1250220381903843328']},
#               'author_id': '312362691',
#               'context_annotations': [{'domain': {'description': 'Entity '
#                                                                  'Service top '
#                                                                  'level '
#                                                                  'domain, '
#                                                                  'every item '
#                                                                  'that is in '
#                                                                  'Entity '
#                                                                  'Service '
#                                                                  'should be in '
#                                                                  'this domain',
#                                                   'id': '30',
#                                                   'name': 'Entities [Entity '
#                                                           'Service]'},
#                                        'entity': {'description': 'Science',
#                                                   'id': '854692455005921281',
#                                                   'name': 'Science'}},
#                                       {'domain': {'description': 'A grouping '
#                                                                  'of interests '
#                                                                  'and hobbies '
#                                                                  'entities, '
#                                                                  'like Novelty '
#                                                                  'Food or '
#                                                                  'Destinations',
#                                                   'id': '66',
#                                                   'name': 'Interests and '
#                                                           'Hobbies Category'},
#                                        'entity': {'description': 'Weather',
#                                                   'id': '857083369514876928',
#                                                   'name': 'Weather'}},
#                                       {'domain': {'description': 'Ongoing News '
#                                                                  'Stories like '
#                                                                  "'Brexit'",
#                                                   'id': '123',
#                                                   'name': 'Ongoing News Story'},
#                                        'entity': {'id': '1220701888179359745',
#                                                   'name': 'COVID-19'}}],
#               'conversation_id': '1250217682533642240',
#               'created_at': '2020-04-15T00:32:23.000Z',
#               'entities': {'urls': [{'display_url': 'pic.twitter.com/7yeQQ6gLNo',
#                                      'end': 82,
#                                      'expanded_url': 'https://twitter.com/ucoptempe/status/1250220389323526146/photo/1',
#                                      'start': 59,
#                                      'url': 'https://t.co/7yeQQ6gLNo'}]},
#               'id': '1250220389323526146',
#               'lang': 'en',
#               'public_metrics': {'like_count': 0,
#                                  'quote_count': 0,
#                                  'reply_count': 1,
#                                  'retweet_count': 0},
#               'text': '13. Cold weather and snow CANNOT kill the new '
#                       'coronavirus. https://t.co/7yeQQ6gLNo'},
#      'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                              'description': '#prinsip Rukun Negara #prinsip '
#                                             'dalam hidup',
#                              'entities': {'description': {'hashtags': [{'end': 8,
#                                                                         'start': 0,
#                                                                         'tag': 'prinsip'},
#                                                                        {'end': 30,
#                                                                         'start': 22,
#                                                                         'tag': 'prinsip'}]}},
#                              'id': '312362691',
#                              'location': 'Bera, Pahang',
#                              'name': '🇲🇾ybk🇲🇾',
#                              'protected': False,
#                              'public_metrics': {'followers_count': 406,
#                                                 'following_count': 2353,
#                                                 'listed_count': 1,
#                                                 'tweet_count': 26352},
#                              'username': 'ucoptempe',
#                              'verified': False}]}},
#  10: {'data': {'attachments': {'media_keys': ['3_1250220519367966721']},
#                'author_id': '312362691',
#                'context_annotations': [{'domain': {'description': 'Ongoing '
#                                                                   'News '
#                                                                   'Stories '
#                                                                   'like '
#                                                                   "'Brexit'",
#                                                    'id': '123',
#                                                    'name': 'Ongoing News '
#                                                            'Story'},
#                                         'entity': {'id': '1220701888179359745',
#                                                    'name': 'COVID-19'}},
#                                        {'domain': {'description': 'Entity '
#                                                                   'Service '
#                                                                   'related '
#                                                                   'Events '
#                                                                   'domain',
#                                                    'id': '29',
#                                                    'name': 'Events [Entity '
#                                                            'Service]'},
#                                         'entity': {'description': 'This page '
#                                                                   'is a '
#                                                                   'timeline of '
#                                                                   'Tweets with '
#                                                                   'the latest '
#                                                                   'information '
#                                                                   'and updates '
#                                                                   'on COVID-19 '
#                                                                   'from '
#                                                                   'experts, '
#                                                                   'journalists, '
#                                                                   'health '
#                                                                   'authorities '
#                                                                   'and other '
#                                                                   'trusted '
#                                                                   'sources '
#                                                                   'from around '
#                                                                   'the world. '
#                                                                   'For more on '
#                                                                   'COVID-19, '
#                                                                   'visit: '
#                                                                   'twitter.com/explore/tabs/covid-19',
#                                                    'id': '1219057585707315201',
#                                                    'name': 'COVID-19: Latest '
#                                                            'news updates from '
#                                                            'around the '
#                                                            'world'}}],
#                'conversation_id': '1250217682533642240',
#                'created_at': '2020-04-15T00:32:56.000Z',
#                'entities': {'urls': [{'display_url': 'pic.twitter.com/ylKa2F40vu',
#                                       'end': 98,
#                                       'expanded_url': 'https://twitter.com/ucoptempe/status/1250220527005753344/photo/1',
#                                       'start': 75,
#                                       'url': 'https://t.co/ylKa2F40vu'}]},
#                'id': '1250220527005753344',
#                'lang': 'en',
#                'public_metrics': {'like_count': 0,
#                                   'quote_count': 0,
#                                   'reply_count': 1,
#                                   'retweet_count': 0},
#                'text': '14. COVID-19 virus can be transmitted in areas with '
#                        'hot and humid climates https://t.co/ylKa2F40vu'},
#       'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                               'description': '#prinsip Rukun Negara #prinsip '
#                                              'dalam hidup',
#                               'entities': {'description': {'hashtags': [{'end': 8,
#                                                                          'start': 0,
#                                                                          'tag': 'prinsip'},
#                                                                         {'end': 30,
#                                                                          'start': 22,
#                                                                          'tag': 'prinsip'}]}},
#                               'id': '312362691',
#                               'location': 'Bera, Pahang',
#                               'name': '🇲🇾ybk🇲🇾',
#                               'protected': False,
#                               'public_metrics': {'followers_count': 406,
#                                                  'following_count': 2353,
#                                                  'listed_count': 1,
#                                                  'tweet_count': 26352},
#                               'username': 'ucoptempe',
#                               'verified': False}]}},
#  11: {'data': {'attachments': {'media_keys': ['3_1250220784812830720']},
#                'author_id': '312362691',
#                'context_annotations': [{'domain': {'description': 'Top level '
#                                                                   'interests '
#                                                                   'and hobbies '
#                                                                   'groupings, '
#                                                                   'like Food '
#                                                                   'or Travel',
#                                                    'id': '65',
#                                                    'name': 'Interests and '
#                                                            'Hobbies Vertical'},
#                                         'entity': {'description': 'Drinks',
#                                                    'id': '834828264786898945',
#                                                    'name': 'Drinks'}},
#                                        {'domain': {'description': 'Interests, '
#                                                                   'opinions, '
#                                                                   'and '
#                                                                   'behaviors '
#                                                                   'of '
#                                                                   'individuals, '
#                                                                   'groups, or '
#                                                                   'cultures; '
#                                                                   'like '
#                                                                   'Speciality '
#                                                                   'Cooking or '
#                                                                   'Theme Parks',
#                                                    'id': '67',
#                                                    'name': 'Interests and '
#                                                            'Hobbies'},
#                                         'entity': {'description': 'Drink '
#                                                                   'Experience',
#                                                    'id': '1006278636842782720',
#                                                    'name': 'Drink Experience'}},
#                                        {'domain': {'description': 'Ongoing '
#                                                                   'News '
#                                                                   'Stories '
#                                                                   'like '
#                                                                   "'Brexit'",
#                                                    'id': '123',
#                                                    'name': 'Ongoing News '
#                                                            'Story'},
#                                         'entity': {'id': '1220701888179359745',
#                                                    'name': 'COVID-19'}}],
#                'conversation_id': '1250217682533642240',
#                'created_at': '2020-04-15T00:33:59.000Z',
#                'entities': {'urls': [{'display_url': 'pic.twitter.com/ZrLN61q046',
#                                       'end': 103,
#                                       'expanded_url': 'https://twitter.com/ucoptempe/status/1250220791544705025/photo/1',
#                                       'start': 80,
#                                       'url': 'https://t.co/ZrLN61q046'}]},
#                'id': '1250220791544705025',
#                'lang': 'en',
#                'public_metrics': {'like_count': 0,
#                                   'quote_count': 0,
#                                   'reply_count': 1,
#                                   'retweet_count': 0},
#                'text': '15. Drinking alcohol does not protect you against '
#                        'COVID-19 and can be dangerous https://t.co/ZrLN61q046'},
#       'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                               'description': '#prinsip Rukun Negara #prinsip '
#                                              'dalam hidup',
#                               'entities': {'description': {'hashtags': [{'end': 8,
#                                                                          'start': 0,
#                                                                          'tag': 'prinsip'},
#                                                                         {'end': 30,
#                                                                          'start': 22,
#                                                                          'tag': 'prinsip'}]}},
#                               'id': '312362691',
#                               'location': 'Bera, Pahang',
#                               'name': '🇲🇾ybk🇲🇾',
#                               'protected': False,
#                               'public_metrics': {'followers_count': 406,
#                                                  'following_count': 2353,
#                                                  'listed_count': 1,
#                                                  'tweet_count': 26352},
#                               'username': 'ucoptempe',
#                               'verified': False}]}},
#  12: {'data': {'attachments': {'media_keys': ['3_1250220971400654849']},
#                'author_id': '312362691',
#                'context_annotations': [{'domain': {'description': 'Ongoing '
#                                                                   'News '
#                                                                   'Stories '
#                                                                   'like '
#                                                                   "'Brexit'",
#                                                    'id': '123',
#                                                    'name': 'Ongoing News '
#                                                            'Story'},
#                                         'entity': {'id': '1220701888179359745',
#                                                    'name': 'COVID-19'}},
#                                        {'domain': {'description': 'Entity '
#                                                                   'Service '
#                                                                   'related '
#                                                                   'Events '
#                                                                   'domain',
#                                                    'id': '29',
#                                                    'name': 'Events [Entity '
#                                                            'Service]'},
# ...
#                                                                   'visit: '
#                                                                   'twitter.com/explore/tabs/covid-19',
#                                                    'id': '1219057585707315201',
#                                                    'name': 'COVID-19: Latest '
#                                                            'news updates from '
#                                                            'around the '
#                                                            'world'}}],
#                'conversation_id': '1250217682533642240',
#                'created_at': '2020-04-15T00:35:22.000Z',
#                'entities': {'urls': [{'display_url': 'pic.twitter.com/yrjUM5qniK',
#                                       'end': 154,
#                                       'expanded_url': 'https://twitter.com/ucoptempe/status/1250221140603047937/photo/1',
#                                       'start': 131,
#                                       'url': 'https://t.co/yrjUM5qniK'}]},
#                'id': '1250221140603047937',
#                'lang': 'en',
#                'public_metrics': {'like_count': 0,
#                                   'quote_count': 0,
#                                   'reply_count': 1,
#                                   'retweet_count': 0},
#                'text': '17. You can recover from the coronavirus disease '
#                        '(COVID-19). Catching the new coronavirus DOES NOT mean '
#                        'you will have it for life. https://t.co/yrjUM5qniK'},
#       'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                               'description': '#prinsip Rukun Negara #prinsip '
#                                              'dalam hidup',
#                               'entities': {'description': {'hashtags': [{'end': 8,
#                                                                          'start': 0,
#                                                                          'tag': 'prinsip'},
#                                                                         {'end': 30,
#                                                                          'start': 22,
#                                                                          'tag': 'prinsip'}]}},
#                               'id': '312362691',
#                               'location': 'Bera, Pahang',
#                               'name': '🇲🇾ybk🇲🇾',
#                               'protected': False,
#                               'public_metrics': {'followers_count': 406,
#                                                  'following_count': 2353,
#                                                  'listed_count': 1,
#                                                  'tweet_count': 26352},
#                               'username': 'ucoptempe',
#                               'verified': False}]}},
#  14: {'data': {'attachments': {'media_keys': ['3_1250221260648243200']},
#                'author_id': '312362691',
#                'context_annotations': [{'domain': {'description': 'Ongoing '
#                                                                   'News '
#                                                                   'Stories '
#                                                                   'like '
#                                                                   "'Brexit'",
#                                                    'id': '123',
#                                                    'name': 'Ongoing News '
#                                                            'Story'},
#                                         'entity': {'id': '1220701888179359745',
#                                                    'name': 'COVID-19'}},
#                                        {'domain': {'description': 'Entity '
#                                                                   'Service '
#                                                                   'related '
#                                                                   'Events '
#                                                                   'domain',
#                                                    'id': '29',
#                                                    'name': 'Events [Entity '
#                                                            'Service]'},
#                                         'entity': {'description': 'This page '
#                                                                   'is a '
#                                                                   'timeline of '
#                                                                   'Tweets with '
#                                                                   'the latest '
#                                                                   'information '
#                                                                   'and updates '
#                                                                   'on COVID-19 '
#                                                                   'from '
#                                                                   'experts, '
#                                                                   'journalists, '
#                                                                   'health '
#                                                                   'authorities '
#                                                                   'and other '
#                                                                   'trusted '
#                                                                   'sources '
#                                                                   'from around '
#                                                                   'the world. '
#                                                                   'For more on '
#                                                                   'COVID-19, '
#                                                                   'visit: '
#                                                                   'twitter.com/explore/tabs/covid-19',
#                                                    'id': '1219057585707315201',
#                                                    'name': 'COVID-19: Latest '
#                                                            'news updates from '
#                                                            'around the '
#                                                            'world'}}],
#                'conversation_id': '1250217682533642240',
#                'created_at': '2020-04-15T00:35:54.000Z',
#                'entities': {'urls': [{'display_url': 'pic.twitter.com/aOQKrrwaBv',
#                                       'end': 151,
#                                       'expanded_url': 'https://twitter.com/ucoptempe/status/1250221275827470336/photo/1',
#                                       'start': 128,
#                                       'url': 'https://t.co/aOQKrrwaBv'}]},
#                'id': '1250221275827470336',
#                'lang': 'en',
#                'public_metrics': {'like_count': 0,
#                                   'quote_count': 0,
#                                   'reply_count': 1,
#                                   'retweet_count': 0},
#                'text': '18. Exposing yourself to the sun or to temperatures '
#                        'higher than 25C degrees DOES NOT prevent the '
#                        'coronavirus disease (COVID-19) '
#                        'https://t.co/aOQKrrwaBv'},
#       'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                               'description': '#prinsip Rukun Negara #prinsip '
#                                              'dalam hidup',
#                               'entities': {'description': {'hashtags': [{'end': 8,
#                                                                          'start': 0,
#                                                                          'tag': 'prinsip'},
#                                                                         {'end': 30,
#                                                                          'start': 22,
#                                                                          'tag': 'prinsip'}]}},
#                               'id': '312362691',
#                               'location': 'Bera, Pahang',
#                               'name': '🇲🇾ybk🇲🇾',
#                               'protected': False,
#                               'public_metrics': {'followers_count': 406,
#                                                  'following_count': 2353,
#                                                  'listed_count': 1,
#                                                  'tweet_count': 26352},
#                               'username': 'ucoptempe',
#                               'verified': False}]}},
#  15: {'data': {'attachments': {'media_keys': ['3_1250221329959116800']},
#                'author_id': '312362691',
#                'context_annotations': [{'domain': {'description': 'Entity '
#                                                                   'Service top '
#                                                                   'level '
#                                                                   'domain, '
#                                                                   'every item '
#                                                                   'that is in '
#                                                                   'Entity '
#                                                                   'Service '
#                                                                   'should be '
#                                                                   'in this '
#                                                                   'domain',
#                                                    'id': '30',
#                                                    'name': 'Entities [Entity '
#                                                            'Service]'},
#                                         'entity': {'description': '5G',
#                                                    'id': '1085628093627195392',
#                                                    'name': '5G'}},
#                                        {'domain': {'description': 'Ongoing '
#                                                                   'News '
#                                                                   'Stories '
#                                                                   'like '
#                                                                   "'Brexit'",
#                                                    'id': '123',
#                                                    'name': 'Ongoing News '
#                                                            'Story'},
#                                         'entity': {'id': '1220701888179359745',
#                                                    'name': 'COVID-19'}},
#                                        {'domain': {'description': 'Entity '
#                                                                   'Service '
#                                                                   'related '
#                                                                   'Events '
#                                                                   'domain',
#                                                    'id': '29',
#                                                    'name': 'Events [Entity '
#                                                            'Service]'},
#                                         'entity': {'description': 'This page '
#                                                                   'is a '
#                                                                   'timeline of '
#                                                                   'Tweets with '
#                                                                   'the latest '
#                                                                   'information '
#                                                                   'and updates '
#                                                                   'on COVID-19 '
#                                                                   'from '
#                                                                   'experts, '
#                                                                   'journalists, '
#                                                                   'health '
#                                                                   'authorities '
#                                                                   'and other '
#                                                                   'trusted '
#                                                                   'sources '
#                                                                   'from around '
#                                                                   'the world. '
#                                                                   'For more on '
#                                                                   'COVID-19, '
#                                                                   'visit: '
#                                                                   'twitter.com/explore/tabs/covid-19',
#                                                    'id': '1219057585707315201',
#                                                    'name': 'COVID-19: Latest '
#                                                            'news updates from '
#                                                            'around the '
#                                                            'world'}}],
#                'conversation_id': '1250217682533642240',
#                'created_at': '2020-04-15T00:36:25.000Z',
#                'entities': {'urls': [{'display_url': 'pic.twitter.com/VjqelBmpTn',
#                                       'end': 69,
#                                       'expanded_url': 'https://twitter.com/ucoptempe/status/1250221402822545410/photo/1',
#                                       'start': 46,
#                                       'url': 'https://t.co/VjqelBmpTn'}]},
#                'id': '1250221402822545410',
#                'lang': 'en',
#                'public_metrics': {'like_count': 0,
#                                   'quote_count': 0,
#                                   'reply_count': 0,
#                                   'retweet_count': 0},
#                'text': '19. 5G mobile networks DO NOT spread COVID-19 '
#                        'https://t.co/VjqelBmpTn'},
#       'includes': {'users': [{'created_at': '2011-06-07T00:46:08.000Z',
#                               'description': '#prinsip Rukun Negara #prinsip '
#                                              'dalam hidup',
#                               'entities': {'description': {'hashtags': [{'end': 8,
#                                                                          'start': 0,
#                                                                          'tag': 'prinsip'},
#                                                                         {'end': 30,
#                                                                          'start': 22,
#                                                                          'tag': 'prinsip'}]}},
#                               'id': '312362691',
#                               'location': 'Bera, Pahang',
#                               'name': '🇲🇾ybk🇲🇾',
#                               'protected': False,
#                               'public_metrics': {'followers_count': 406,
#                                                  'following_count': 2353,
#                                                  'listed_count': 1,
#                                                  'tweet_count': 26352},
#                               'username': 'ucoptempe',
#                               'verified': False}]}}}
